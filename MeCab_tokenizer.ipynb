# %% [markdown]
# # MeCabによる形態素解析

# %%
import MeCab

tagger = MeCab.Tagger ('mecabrc') 
tagger.parse('')# 実行の準備

token=tagger.parseToNode('いつもながら、パスタランチはお気軽でいい感じ。今回は2種類のパスタを2人でシェア盛りにしてもらいました。\
エビのオイルベースのショートパスタとトマトパスタ。あっさりした味付けで、いつの間にかペロリと食べてしまいます。お野菜を多く使ってヘルシーな内容 \
になっていました。ブルーベリージャムのババロアは定番なのだとか。いつ行っても食べられそうで嬉しいです。')

    
while token:
    print(token.surface,token.feature)
    token = token.next
# Out:
#  BOS/EOS,*,*,*,*,*,*,*,*
# いつも 副詞,一般,*,*,*,*,いつも,イツモ,イツモ
# ながら 助詞,接続助詞,*,*,*,*,ながら,ナガラ,ナガラ
# 、 記号,読点,*,*,*,*,、,、,、
# パスタ 名詞,一般,*,*,*,*,パスタ,パスタ,パスタ
# ランチ 名詞,一般,*,*,*,*,ランチ,ランチ,ランチ
# は 助詞,係助詞,*,*,*,*,は,ハ,ワ
# お 接頭詞,名詞接続,*,*,*,*,お,オ,オ
# 気軽 名詞,形容動詞語幹,*,*,*,*,気軽,キガル,キガル
# で 助動詞,*,*,*,特殊・ダ,連用形,だ,デ,デ
# いい 形容詞,自立,*,*,形容詞・イイ,基本形,いい,イイ,イイ
# 感じ 名詞,一般,*,*,*,*,感じ,カンジ,カンジ
# 。 記号,句点,*,*,*,*,。,。,。
# 今回 名詞,副詞可能,*,*,*,*,今回,コンカイ,コンカイ
# は 助詞,係助詞,*,*,*,*,は,ハ,ワ
# 2 名詞,数,*,*,*,*,*
# 種類 名詞,一般,*,*,*,*,種類,シュルイ,シュルイ
# の 助詞,連体化,*,*,*,*,の,ノ,ノ
# パスタ 名詞,一般,*,*,*,*,パスタ,パスタ,パスタ
# を 助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 2 名詞,数,*,*,*,*,*
# 人 名詞,接尾,助数詞,*,*,*,人,ニン,ニン
# で 助詞,格助詞,一般,*,*,*,で,デ,デ
# シェア 名詞,一般,*,*,*,*,シェア,シェア,シェア
# 盛り 名詞,接尾,一般,*,*,*,盛り,ザカリ,ザカリ
# に 助詞,格助詞,一般,*,*,*,に,ニ,ニ
# し 動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# て 助詞,接続助詞,*,*,*,*,て,テ,テ
# もらい 動詞,非自立,*,*,五段・ワ行促音便,連用形,もらう,モライ,モライ
# まし 助動詞,*,*,*,特殊・マス,連用形,ます,マシ,マシ
# た 助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# 。 記号,句点,*,*,*,*,。,。,。
# エビ 名詞,一般,*,*,*,*,エビ,エビ,エビ
# の 助詞,連体化,*,*,*,*,の,ノ,ノ
# オイル 名詞,一般,*,*,*,*,オイル,オイル,オイル
# ベース 名詞,一般,*,*,*,*,ベース,ベース,ベース
# の 助詞,連体化,*,*,*,*,の,ノ,ノ
# ショート 名詞,一般,*,*,*,*,ショート,ショート,ショート
# パスタ 名詞,一般,*,*,*,*,パスタ,パスタ,パスタ
# と 助詞,並立助詞,*,*,*,*,と,ト,ト
# トマト 名詞,一般,*,*,*,*,トマト,トマト,トマト
# パスタ 名詞,一般,*,*,*,*,パスタ,パスタ,パスタ
# 。 記号,句点,*,*,*,*,。,。,。
# あっさり 副詞,助詞類接続,*,*,*,*,あっさり,アッサリ,アッサリ
# し 動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# た 助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# 味付け 名詞,サ変接続,*,*,*,*,味付け,アジツケ,アジツケ
# で 助詞,格助詞,一般,*,*,*,で,デ,デ
# 、 記号,読点,*,*,*,*,、,、,、
# いつの間にか 副詞,一般,*,*,*,*,いつの間にか,イツノマニカ,イツノマニカ
# ペロリ 名詞,一般,*,*,*,*,*
# と 助詞,格助詞,引用,*,*,*,と,ト,ト
# 食べ 動詞,自立,*,*,一段,連用形,食べる,タベ,タベ
# て 助詞,接続助詞,*,*,*,*,て,テ,テ
# しまい 動詞,非自立,*,*,五段・ワ行促音便,連用形,しまう,シマイ,シマイ
# ます 助動詞,*,*,*,特殊・マス,基本形,ます,マス,マス
# 。 記号,句点,*,*,*,*,。,。,。
# お 接頭詞,名詞接続,*,*,*,*,お,オ,オ
# 野菜 名詞,一般,*,*,*,*,野菜,ヤサイ,ヤサイ
# を 助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 多く 形容詞,自立,*,*,形容詞・アウオ段,連用テ接続,多い,オオク,オーク
# 使っ 動詞,自立,*,*,五段・ワ行促音便,連用タ接続,使う,ツカッ,ツカッ
# て 助詞,接続助詞,*,*,*,*,て,テ,テ
# ヘルシー 名詞,形容動詞語幹,*,*,*,*,ヘルシー,ヘルシー,ヘルシー
# な 助動詞,*,*,*,特殊・ダ,体言接続,だ,ナ,ナ
# 内容 名詞,一般,*,*,*,*,内容,ナイヨウ,ナイヨー
# に 助詞,格助詞,一般,*,*,*,に,ニ,ニ
# なっ 動詞,自立,*,*,五段・ラ行,連用タ接続,なる,ナッ,ナッ
# て 助詞,接続助詞,*,*,*,*,て,テ,テ
# い 動詞,非自立,*,*,一段,連用形,いる,イ,イ
# まし 助動詞,*,*,*,特殊・マス,連用形,ます,マシ,マシ
# た 助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# 。 記号,句点,*,*,*,*,。,。,。
# ブルーベリー 名詞,一般,*,*,*,*,ブルーベリー,ブルーベリー,ブルーベリー
# ジャム 名詞,一般,*,*,*,*,ジャム,ジャム,ジャム
# の 助詞,連体化,*,*,*,*,の,ノ,ノ
# ババロア 名詞,一般,*,*,*,*,ババロア,ババロア,ババロア
# は 助詞,係助詞,*,*,*,*,は,ハ,ワ
# 定番 名詞,一般,*,*,*,*,定番,テイバン,テイバン
# な 助動詞,*,*,*,特殊・ダ,体言接続,だ,ナ,ナ
# の 名詞,非自立,一般,*,*,*,の,ノ,ノ
# だ 助動詞,*,*,*,特殊・ダ,基本形,だ,ダ,ダ
# と 助詞,格助詞,引用,*,*,*,と,ト,ト
# か 助詞,副助詞／並立助詞／終助詞,*,*,*,*,か,カ,カ
# 。 記号,句点,*,*,*,*,。,。,。
# いつ 名詞,代名詞,一般,*,*,*,いつ,イツ,イツ
# 行っ 動詞,自立,*,*,五段・カ行促音便,連用タ接続,行く,イッ,イッ
# て 助詞,接続助詞,*,*,*,*,て,テ,テ
# も 助詞,係助詞,*,*,*,*,も,モ,モ
# 食べ 動詞,自立,*,*,一段,未然形,食べる,タベ,タベ
# られ 動詞,接尾,*,*,一段,連用形,られる,ラレ,ラレ
# そう 名詞,接尾,助動詞語幹,*,*,*,そう,ソウ,ソー
# で 助動詞,*,*,*,特殊・ダ,連用形,だ,デ,デ
# 嬉しい 形容詞,自立,*,*,形容詞・イ段,基本形,嬉しい,ウレシイ,ウレシイ
# です 助動詞,*,*,*,特殊・デス,基本形,です,デス,デス
# 。 記号,句点,*,*,*,*,。,。,。
#  BOS/EOS,*,*,*,*,*,*,*,*

# %% [markdown]
# ## 演習
# 1. 上記のプログラムを修正して、名詞だけを表示するようにせよ。
# ヒント：token.feature　に品詞属性が入っている。属性は、カンマ区切りの文字列
# Janomeのプログラムを参考にしてください
# 2. 同様に動詞だけを表示するようにせよ。
# 動詞には活用形があるがこのままだと問題がある。何が問題だろうか。
# 活用形を基本形にして表示するには？

# %% [markdown]
# # Neologd辞書を使ったフレーズ認識
# ショート，パスタ　→　ショートパスタ
# ブルーベリー，ジャム　→　ブルーベリージャム
# になっている。

# %%
import MeCab

tagger = MeCab.Tagger("mecabrc -u c:/neologd/NEologd.dic")
tagger.parse('')# 実行の準備

token=tagger.parseToNode('いつもながら、パスタランチはお気軽でいい感じ。今回は2種類のパスタを2人でシェア盛りにしてもらいました。\
エビのオイルベースのショートパスタとトマトパスタ。あっさりした味付けで、いつの間にかペロリと食べてしまいます。お野菜を多く使ってヘルシーな内容 \
になっていました。ブルーベリージャムのババロアは定番なのだとか。いつ行っても食べられそうで嬉しいです。')

 
while token:
    print(token.surface,token.feature)
    token = token.next
# Out:
#  BOS/EOS,*,*,*,*,*,*,*,*
# いつも 副詞,一般,*,*,*,*,いつも,イツモ,イツモ
# ながら 助詞,接続助詞,*,*,*,*,ながら,ナガラ,ナガラ
# 、 記号,読点,*,*,*,*,、,、,、
# パスタ 名詞,一般,*,*,*,*,パスタ,パスタ,パスタ
# ランチ 名詞,一般,*,*,*,*,ランチ,ランチ,ランチ
# は 助詞,係助詞,*,*,*,*,は,ハ,ワ
# お 接頭詞,名詞接続,*,*,*,*,お,オ,オ
# 気軽 名詞,形容動詞語幹,*,*,*,*,気軽,キガル,キガル
# で 助動詞,*,*,*,特殊・ダ,連用形,だ,デ,デ
# いい 形容詞,自立,*,*,形容詞・イイ,基本形,いい,イイ,イイ
# 感じ 名詞,一般,*,*,*,*,感じ,カンジ,カンジ
# 。 記号,句点,*,*,*,*,。,。,。
# 今回 名詞,副詞可能,*,*,*,*,今回,コンカイ,コンカイ
# は 助詞,係助詞,*,*,*,*,は,ハ,ワ
# 2種類 名詞,固有名詞,一般,*,*,*,2種類,ニシュルイ,ニシュルイ
# の 助詞,連体化,*,*,*,*,の,ノ,ノ
# パスタ 名詞,一般,*,*,*,*,パスタ,パスタ,パスタ
# を 助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 2人 名詞,固有名詞,一般,*,*,*,2人,フタリ,フタリ
# で 助詞,格助詞,一般,*,*,*,で,デ,デ
# シェア 名詞,一般,*,*,*,*,シェア,シェア,シェア
# 盛り 名詞,接尾,一般,*,*,*,盛り,ザカリ,ザカリ
# に 助詞,格助詞,一般,*,*,*,に,ニ,ニ
# し 動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# て 助詞,接続助詞,*,*,*,*,て,テ,テ
# もらい 動詞,非自立,*,*,五段・ワ行促音便,連用形,もらう,モライ,モライ
# まし 助動詞,*,*,*,特殊・マス,連用形,ます,マシ,マシ
# た 助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# 。 記号,句点,*,*,*,*,。,。,。
# エビ 名詞,一般,*,*,*,*,エビ,エビ,エビ
# の 助詞,連体化,*,*,*,*,の,ノ,ノ
# オイル 名詞,一般,*,*,*,*,オイル,オイル,オイル
# ベース 名詞,一般,*,*,*,*,ベース,ベース,ベース
# の 助詞,連体化,*,*,*,*,の,ノ,ノ
# ショートパスタ 名詞,固有名詞,一般,*,*,*,ショートパスタ,ショートパスタ,ショートパスタ
# と 助詞,並立助詞,*,*,*,*,と,ト,ト
# トマト 名詞,一般,*,*,*,*,トマト,トマト,トマト
# パスタ 名詞,一般,*,*,*,*,パスタ,パスタ,パスタ
# 。 記号,句点,*,*,*,*,。,。,。
# あっさり 副詞,助詞類接続,*,*,*,*,あっさり,アッサリ,アッサリ
# し 動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# た 助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# 味付け 名詞,サ変接続,*,*,*,*,味付け,アジツケ,アジツケ
# で 助詞,格助詞,一般,*,*,*,で,デ,デ
# 、 記号,読点,*,*,*,*,、,、,、
# いつの間にか 副詞,一般,*,*,*,*,いつの間にか,イツノマニカ,イツノマニカ
# ペロリ 名詞,固有名詞,組織,*,*,*,ペロリ,ペロリ,ペロリ
# と 助詞,格助詞,一般,*,*,*,と,ト,ト
# 食べ 動詞,自立,*,*,一段,連用形,食べる,タベ,タベ
# て 助詞,接続助詞,*,*,*,*,て,テ,テ
# しまい 動詞,非自立,*,*,五段・ワ行促音便,連用形,しまう,シマイ,シマイ
# ます 助動詞,*,*,*,特殊・マス,基本形,ます,マス,マス
# 。 記号,句点,*,*,*,*,。,。,。
# お 接頭詞,名詞接続,*,*,*,*,お,オ,オ
# 野菜 名詞,一般,*,*,*,*,野菜,ヤサイ,ヤサイ
# を 助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 多く 形容詞,自立,*,*,形容詞・アウオ段,連用テ接続,多い,オオク,オーク
# 使っ 動詞,自立,*,*,五段・ワ行促音便,連用タ接続,使う,ツカッ,ツカッ
# て 助詞,接続助詞,*,*,*,*,て,テ,テ
# ヘルシー 名詞,形容動詞語幹,*,*,*,*,ヘルシー,ヘルシー,ヘルシー
# な 助動詞,*,*,*,特殊・ダ,体言接続,だ,ナ,ナ
# 内容 名詞,一般,*,*,*,*,内容,ナイヨウ,ナイヨー
# に 助詞,格助詞,一般,*,*,*,に,ニ,ニ
# なっ 動詞,自立,*,*,五段・ラ行,連用タ接続,なる,ナッ,ナッ
# て 助詞,接続助詞,*,*,*,*,て,テ,テ
# い 動詞,非自立,*,*,一段,連用形,いる,イ,イ
# まし 助動詞,*,*,*,特殊・マス,連用形,ます,マシ,マシ
# た 助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# 。 記号,句点,*,*,*,*,。,。,。
# ブルーベリージャム 名詞,固有名詞,一般,*,*,*,ブルーベリージャム,ブルーベリージャム,ブルーベリージャム
# の 助詞,連体化,*,*,*,*,の,ノ,ノ
# ババロア 名詞,一般,*,*,*,*,ババロア,ババロア,ババロア
# は 助詞,係助詞,*,*,*,*,は,ハ,ワ
# 定番 名詞,一般,*,*,*,*,定番,テイバン,テイバン
# な 助動詞,*,*,*,特殊・ダ,体言接続,だ,ナ,ナ
# の 名詞,非自立,一般,*,*,*,の,ノ,ノ
# だ 助動詞,*,*,*,特殊・ダ,基本形,だ,ダ,ダ
# と 助詞,格助詞,引用,*,*,*,と,ト,ト
# か 助詞,副助詞／並立助詞／終助詞,*,*,*,*,か,カ,カ
# 。 記号,句点,*,*,*,*,。,。,。
# いつ 名詞,代名詞,一般,*,*,*,いつ,イツ,イツ
# 行っ 動詞,自立,*,*,五段・カ行促音便,連用タ接続,行く,イッ,イッ
# て 助詞,接続助詞,*,*,*,*,て,テ,テ
# も 助詞,係助詞,*,*,*,*,も,モ,モ
# 食べ 動詞,自立,*,*,一段,未然形,食べる,タベ,タベ
# られ 動詞,接尾,*,*,一段,連用形,られる,ラレ,ラレ
# そう 名詞,接尾,助動詞語幹,*,*,*,そう,ソウ,ソー
# で 助動詞,*,*,*,特殊・ダ,連用形,だ,デ,デ
# 嬉しい 形容詞,自立,*,*,形容詞・イ段,基本形,嬉しい,ウレシイ,ウレシイ
# です 助動詞,*,*,*,特殊・デス,基本形,です,デス,デス
# 。 記号,句点,*,*,*,*,。,。,。
#  BOS/EOS,*,*,*,*,*,*,*,*
